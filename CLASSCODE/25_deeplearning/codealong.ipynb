# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../TensorFlow_FILES/DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# #no missing values

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %% [markdown]
# #5.402966e+05	 (value on price-mean column)
# #means 5.4 times 10 to the power of 5.So essentially add in five zeros.

# %% [markdown]
# <h3>Exploratory Data Analysis</h3>

# %%
plt.figure(figsize=(10,6))
sns.displot(data=df['price'],kde=True)

# %%
#1=1lakh(1*1000000[6zeroes])

# %%
sns.countplot(data=df,x='bedrooms',palette='Set1')
# Out:
# C:\Users\kannoth\AppData\Local\Temp\ipykernel_11092\474303286.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='bedrooms',palette='Set1')
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.corr(numeric_only=True)['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# #sqft_living has high corelation with pricing

# %%
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
sns.boxplot(data=df,x='bedrooms',y='price',palette='rainbow')
# Out:
# C:\Users\kannoth\AppData\Local\Temp\ipykernel_11092\254383369.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='bedrooms',y='price',palette='rainbow')
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# <u>distribution of prices per bedrooms.</u>
# <br>
#
# """
# eg:bit of variation in bedrooms ranging between 3 and 7.
#
# """

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.scatterplot(data=df,x='price',y='long')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %% [markdown]
# #here at a longitude -122.2 we can see so many distributions which would be an expensive housing area

# %%
sns.scatterplot(data=df,x='price',y='lat')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %% [markdown]
# #here at a latitude -47.6 we can see so many distributions which would be an expensive housing area

# %%
sns.scatterplot(x='long',y='lat',data=df,hue='price',)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
#grabing everything after the top 1% of houses, which essentially means starting at index, integer location 216,
#ie.grabbing 99% bottom of houses as per price sorted in ascending order
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price',edgecolor=None,palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# we can kind of assume 99% of all houses are going to be somewhere either on the waterfront on this top northern edge or or in this expensive area of King County."

# %%
sns.boxplot(x='waterfront',data=df,y='price')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# looks like if you are on the waterfront,you are more likely to be more expensive

# %%
df.drop('id',axis=1,inplace=True)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %% [markdown]
# datetime object which means I can begin to perform feature engineering off this
# we can extract the year component and the month component

# %%
"""
def year_extraction(date):
  return date.year

df['year']=df['date'].apply(lambda date:date.year)
"""
# Out:
# "\ndef year_extraction(date):\n  return date.year\n\ndf['year']=df['date'].apply(lambda date:date.year)\n"

# %%
df['year']=df['date'].apply(lambda date:date.year)
df['month']=df['date'].apply(lambda date:date.month)

# %% [markdown]
# and this is essentially feature engineering
# because these features were technically hidden inside of the string date
# now I'm creating new columns to try to extract or engineer more information off my original features

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
sns.boxplot(data=df,x='month',y='price',palette='Set1')
# Out:
# C:\Users\kannoth\AppData\Local\Temp\ipykernel_11092\3790295525.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='month',y='price',palette='Set1')
# <Axes: xlabel='month', ylabel='price'>

# %%
sns.countplot(data=df,x='month',)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
#plt.plot(df.groupby('month').mean()['price'],df.groupby('month').mean()['month'])
df.groupby('month').mean()['price'].sort_values(ascending=False)
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].sort_values(ascending=False)
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# probably too much to just call pd, get dummies on this, and then have 70 categories of zip codes.
# So for this particular case we will drop the zip code column  (70 categories is just too much for us)
#
# However, what we could do is with a little bit of domain experience and domain knowledge,maybe try to categorize this based off what we know are expensive zip codes versus maybe less expensive zip codes.
#
# Or we could do some sort of mapp  or grouping to do zip codes in the south zip codes in the middle and zip codes in the north, east and west

# %%
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# So a lot of times you'll have to make the decision in feature engineering
# if you wanna make a continuous variable categorical,or just keep it as continuous.

# %% [markdown]
# <h4>DATA PREPORCESSING AN CREATING A MODEL</h4>

# %%
X=df.drop('price',axis=1).values
y=df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X.shape
# Out:
# (21597, 19)

# %%
model=Sequential()

model.add(Dense(19,activation='relu'),)
model.add(Dense(19,activation='relu'),)
model.add(Dense(19,activation='relu'),)
model.add(Dense(19,activation='relu'),)

model.add(Dense(1))

model.compile(optimizer='adam',loss='mean_squared_error')

#optimizer=adam,rmsporp

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 450107539456.0000 - val_loss: 418916106240.0000
# Epoch 2/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 420887003136.0000 - val_loss: 414836621312.0000
# Epoch 3/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 431503179776.0000 - val_loss: 376404344832.0000
# Epoch 4/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 358589464576.0000 - val_loss: 244503937024.0000
# Epoch 5/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 212782333952.0000 - val_loss: 109201956864.0000
# Epoch 6/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 109477584896.0000 - val_loss: 95196192768.0000
# Epoch 7/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 106670768128.0000 - val_loss: 93558841344.0000
# Epoch 8/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 97741570048.0000 - val_loss: 91903623168.0000
# Epoch 9/400
# ...

# %% [markdown]
# pass in ***validation data.***
#   is after each epoch of training on the training data,we'll quickly run the test data and check our loss on the test data
#     so that way we can keep a tracking of how we're performing not just on our training data but also on our test data.
#
# note:Keep in mind, this test data will not actually affect the weights or biases of our network.
#
# So Keras isn't going to update your model based off the test data or validation data.
#   Instead, it will only use the training data as it's updating the weights and biases and continue to essentially check how well it's doing on not just the training data, but also the validation data.

# %% [markdown]
# ***batch_size***
# because this is a larger dataset,we're gonna feed in our data in batches.
# <br>
# It's very typical to do batch_sizes in powers of two(64, 128, 256.)
# <br>
# smaller the batch_size,the longer training is going to take,but the less likely you're going to overfit to your data <u>because you're not passing in your entire training set at once.Instead, you're focusing on these smaller batches.</u>

# %% [markdown]
# <h4>MODEL EVALUATION AND PREDICTION</h4>

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302405e+11  4.189161e+11
# 1    4.290908e+11  4.148366e+11
# 2    4.124729e+11  3.764043e+11
# 3    3.301726e+11  2.445039e+11
# 4    1.740997e+11  1.092020e+11
# ..            ...           ...
# 395  2.948406e+10  2.719036e+10
# 396  2.950172e+10  2.723659e+10
# 397  2.948021e+10  2.723512e+10
# 398  2.950004e+10  2.715899e+10
# 399  2.948218e+10  2.715272e+10
#
# [400 rows x 2 columns]

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# this is exactly the kind of signal we want
# <br>
# where there's decrease in both the training loss and the validation loss.
# And then there is no increase so far in the validation set<br>
# And actually what that means is technically,<u>we could have continued training</u>.
#
# <small>
# towards the tail end,we're actually not improving that much.So after 400 epochs, it looks like we're kind of hovering around this particular loss value and the decreasing is happening much slower.
# <br>
# But because the validation loss is also going down,that's an indicator that we could continue training without overfitting to our training data.
# <br>
# <i>
# If you saw this orange line begin to spike after some of these epochs, so it started to go up and up and up,that means you're overfitting to the training data ,because now you have a much larger loss on validation data
# <i>
# </small>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions=model.predict(X_test)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mean_squared_error(y_test,predictions)
# Out:
# 27152715678.62143

# %% [markdown]
# <b>
# This is a very large value, which kind of makes sense<br><u>because we're dealing with the prices of houses.So we're squaring those.</u>
# </b>

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 164780.81101457606

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 101496.4792160976

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
"""taking mean"""
5.402966e+05
# Out:
# 540296.6

# %% [markdown]
# that the average price of the house is around $540,000<br>
# In our case, our mean absolute error is about $100,000.<br>
# <u>We're off by around 20%, so not great, not horrible eithe</u>

# %%
(1/100)*540296.6
101496.479/5402.965999999999
# Out:
# 18.785326244881055

# %% [markdown]
# <u>#explained_variance_score</u><br>
#
# So the best possible score is 1.0, and what this does,
# <br>
# t tells you how much variance is being explained by your actual model.

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7952596356471457

# %%
plt.figure(figsize=(12,12))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %% [markdown]
# So these really expensive houses we're actually not good at predicting the price
# <br>
# but we're pretty good at predicting the prices of houses between zero and $2 million.

# %% [markdown]
# <b>
# What may be worth it is to retrain our model just on that bottom 99% of houses.
# </b>
# And so if we come up to a situation where our maybe sale price is over $3 million, we'll just say, "Sorry our model's not good enough for this,"and we'll only refit to that bottom 99%.

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
"""
single_house2=single_house
single_house3=single_house
print(single_house2.values.reshape(-1,19))
print(single_house3.values.reshape(1,19))
"""
# Out:
# '\nsingle_house2=single_house\nsingle_house3=single_house\nprint(single_house2.values.reshape(-1,19))\nprint(single_house3.values.reshape(1,19))\n'

# %%
single_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  2.01400e+03,  1.00000e+01])

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# array([[281600.16]], dtype=float32)

# %%
df.iloc[0]['price']
# Out:
# 221900.0

# %% [markdown]
# true price it sold -> $221,000
# <br>
# predictaed price  -> $281,600

# %% [markdown]
# <h5>SUMMARY</h5>
# 1)We've been able to do a little bit of feature engineering,
# <br>
# 2)do a little bit of exploratory data analysis
# <br>
# 3)create and train a model
# <br>
# 4)then get back a relatively reasonable model in order to predict the prices of houses.
# <br>
# <br>
# <b>
# it looks like we're more or less explaining quite a bit of variance up to 80% of the variance in the pricing.
# </b>

# %% [markdown]
# <h3>STEPS</h3>
# <br>
# 1)find missing data<br>
# 2)fix it<br>
# 3)visualising using seaborn<br>
# 4)drop or edit dataframe wherever reuires<br>
# 5)import sequential,dense from tensorflow.keras.models<br>
# 6)standardise training and test data<br>
# 7)check errors
# [mean_absolute_error,mean_squared_error,explained_variance_score]<br>
# [TIP:look mean of the feature from dataframe which we have to predict .and then compare that value with the mean absolute error.if mean absoluter is a small percentage of mean of the feature we predict we almost have a good model]<br>
# 8)create a duplicate data and give it ot model for prediction
