# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df1=pd.read_csv('df1',index_col=0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=30,edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# #hist

# %%
df1['A'].hist(grid=False,edgecolor='black',bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30,edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #plot.area

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.4,)
# Out:
# <Axes: >

# %% [markdown]
# #plot.bar

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True,)
# Out:
# <Axes: >

# %% [markdown]
# #plot.hist

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #plot.line

# %%
df1.plot.line(figsize=(12,3),lw=1)
# Out:
# <Axes: >

# %% [markdown]
# #plot.scatter

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm',)
#c for third dimension as color
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50,cmap='coolwarm',)
#s for third dimension as size of that items in mentioned column ie. size indicates how much give column values(here 'C' are relevent to each other)
# Out:
# f:\EDU CODING\PYTHON STP\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# f:\EDU CODING\PYTHON STP\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# #plot.box

# %%
df2.plot.box(cmap='cool')
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0   -1.842940  0.656526
# 1   -0.371738 -0.203667
# 2    0.446873  0.261805
# 3   -0.042077  0.859934
# 4    0.273460 -1.467919
# ..        ...       ...
# 995  0.390283  1.299278
# 996  0.889448  2.211204
# 997 -0.486738 -0.134691
# 998 -0.594003  0.571909
# 999  0.054248 -2.570132
#
# [1000 rows x 2 columns]

# %% [markdown]
# #plot.hexbin

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
#heaxagons get much darker when there are more points in that part
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# #plot.kde

# %%
df2['a'].plot.kde()
# same as -> df2['a'].plot.density()
# Out:
# <Axes: ylabel='Density'>
