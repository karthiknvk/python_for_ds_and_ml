# %%
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #BARPLOT

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator='std')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator='sum')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
tips[tips['sex']=='Male']['total_bill'].sum()
# Out:
# 3256.8199999999997

# %%
tips[tips['sex']=='Female']['total_bill'].std()
# Out:
# 8.009208988951961

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# #COUNTPLOT

# %%
sns.countplot(x='sex',data=tips)
#same bar plot exept y not chosen, instead show occurrences(count) in  y axis
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #BOXPLOT

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex',palette='cool',)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #VIOLINPLOT

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',palette='cool',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #STRIPPLOT

# %%
sns.stripplot(x='day',y='total_bill',data=tips,palette='cool',hue='sex',)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #SWARMPLOT

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='cool')
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
# Out:
# C:\Users\kannoth\AppData\Local\Temp\ipykernel_5568\2660230099.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=tips,palette='cool')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# <s>FACTORPLOT</s><br>CATPLOT

# %%
#Factorplot is now renamed
"""
Hi everyone, I just want to point out that factorplot is now renamed to catplot and 
"""
# Out:
# '\nHi everyone, I just want to point out that factorplot is now renamed to catplot and \n'

# %%
sns.catplot(x='day',y='total_bill',data=tips,palette='cool',kind='violin')
# Out:
# C:\Users\kannoth\AppData\Local\Temp\ipykernel_5568\3620486242.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='day',y='total_bill',data=tips,palette='cool',kind='violin')

# %% [markdown]
# #boxplot()<br>
# #countplot()<br>
# #violinplot()<br>
# #striplplot()<br>
# #swarmplot()<br>
# #catplot()<br>
